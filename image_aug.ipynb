# %% [markdown]
# # Image Data Augmentation with Keras
#
# ![Horizontal Flip](assets/horizontal_flip.jpg)

# %% [markdown]
# # Import Libraries

# %%
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

from PIL import Image
from matplotlib import pyplot as plt

print('Using TensorFlow', tf.__version__)
# Out:
# Using TensorFlow 2.1.0

# %% [markdown]
# # Rotation
#
# We set the rotation_range to 30 degrees which can randomly rotate the picture 30 degrees either clockwise or counter-clockwise.

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=30)

# %%
image_path = 'images/train/cat/cat.jpg'

plt.imshow(plt.imread(image_path));

# %%
x, y = next(generator.flow_from_directory('images', batch_size=1))
plt.imshow(x[0].astype('uint8'));
# Out:
# Found 1 images belonging to 1 classes.

# %% [markdown]
# # Width and Height Shifts
#
# Here the input is moved horizontally or vertically (randomly of course).

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(
    width_shift_range=[-100, -50, 0, 50, 100],
    height_shift_range=[-50, 0, 50]
)

# %%
x, y = next(generator.flow_from_directory('images', batch_size=1))
plt.imshow(x[0].astype('uint8'));
# Out:
# Found 1 images belonging to 1 classes.

# %% [markdown]
# # Brightness

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(
    brightness_range=(0.5, 2.0)
)

x, y = next(generator.flow_from_directory('images', batch_size=1))
plt.imshow(x[0].astype('uint8'));
# Out:
# Found 1 images belonging to 1 classes.

# %% [markdown]
# # Shear Transformation

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(
    shear_range=30
)

x, y = next(generator.flow_from_directory('images', batch_size=1))
plt.imshow(x[0].astype('uint8'));
# Out:
# Found 1 images belonging to 1 classes.

# %% [markdown]
# # Zoom

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(
    zoom_range=[0.5, 1.2]
)

x, y = next(generator.flow_from_directory('images', batch_size=1))
plt.imshow(x[0].astype('uint8'));
# Out:
# Found 1 images belonging to 1 classes.

# %% [markdown]
# # Channel Shift

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(
    channel_shift_range=100
)

x, y = next(generator.flow_from_directory('images', batch_size=1))
plt.imshow(x[0].astype('uint8'));
# Out:
# Found 1 images belonging to 1 classes.

# %% [markdown]
# # Flipping

# %%
generator = tf.keras.preprocessing.image.ImageDataGenerator(
    horizontal_flip=True,
    vertical_flip=True
)

x, y = next(generator.flow_from_directory('images', batch_size=1))
plt.imshow(x[0].astype('uint8'));
# Out:
# Found 1 images belonging to 1 classes.
